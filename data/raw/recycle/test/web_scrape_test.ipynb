# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import os

# URL of the webpage containing the tables
url = 'https://mangacodex.com/oricon_weekly/2008/04_Abril.php'

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all sections containing the tables
    sections = soup.find_all('section', class_='table_grid')

    # List to store DataFrames
    df_list = []

    # Iterate over each section
    for section in sections:
        # Iterate over each div within the section
        for div in section.find_all('div', recursive=False):
            # Extract the date range
            date_range_div = div.find('div', style=True)
            if date_range_div:
                date_range = date_range_div.get_text(strip=True)

                # Find the table within the div
                table = div.find('table', class_='table')
                if table:
                    # Extract table headers
                    headers = [th.get_text(strip=True) for th in table.find_all('th')]

                    # Extract table rows
                    rows = []
                    for tr in table.find_all('tr')[1:]:  # Skip the header row
                        cells = [td.get_text(strip=True) for td in tr.find_all('td')]
                        if cells:
                            rows.append(cells)

                    # Create DataFrame
                    df = pd.DataFrame(rows, columns=headers)

                    # Add date range column
                    df.insert(0, 'Date Range', date_range)

                    # Store in list
                    df_list.append(df)

    # Combine all DataFrames into a single DataFrame
    final_df = pd.concat(df_list, ignore_index=True)

else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")

# %%
final_df
# Out:
#                                             Date Range  \
# 0    WEEKLY RANKING ---  March 24 · 30 -- (*Since O...
# 1    WEEKLY RANKING ---  March 24 · 30 -- (*Since O...
# 2    WEEKLY RANKING ---  March 24 · 30 -- (*Since O...
# 3    WEEKLY RANKING ---  March 24 · 30 -- (*Since O...
# 4    WEEKLY RANKING ---  March 24 · 30 -- (*Since O...
# ..                                                 ...
# 295              WEEKLY RANKING ---  April 28 · May 04
# 296              WEEKLY RANKING ---  April 28 · May 04
# 297              WEEKLY RANKING ---  April 28 · May 04
# 298              WEEKLY RANKING ---  April 28 · May 04
# 299              WEEKLY RANKING ---  April 28 · May 04
#
#                           TITLE   WEEKLY     TOTAL
# 0             Kimi ni Todoke #6  347.826   347.826
# 1       Fullmetal Alchemist #19  317.252   317.252
# 2          Nodame Cantabile #20  118.994  *118.994
# 3               Bamboo Blade #8  104.365   104.365
# 4                  Tsukihime #6   98.344    98.344
# ..                          ...      ...       ...
# 295         Chi’s Sweet Home #5   19,805    58,051
# 296  Katekyo Hitman Reborn! #19   18,710   470,335
# 297          Kaze no Daichi #46   18,618    23,767
# 298     Kamen Rider Spirits #14   18,556    77,463
# 299    Mahou Sensei Negima! #22   18,471   216,833
#
# [300 rows x 4 columns]

# %%
os.makedirs('test')
final_df.to_csv("test/oricon_charts_2008_04.csv")

# %%
# Out:
# Processing: https://mangacodex.com/oricon_weekly/2008/04_abril.php for 2008-4
# Saved oricon_chart_2008_4.csv
# Processing: https://mangacodex.com/oricon_weekly/2008/05_May.php for 2008-5
# Saved oricon_chart_2008_5.csv
# Processing: https://mangacodex.com/oricon_weekly/2008/06_Junio.php for 2008-6
# Saved oricon_chart_2008_6.csv
# Processing: https://mangacodex.com/oricon_weekly/2008/07_Julio.php for 2008-7
# Saved oricon_chart_2008_7.csv
# Processing: https://mangacodex.com/oricon_weekly/2008/08_Agosto.php for 2008-8
# Saved oricon_chart_2008_8.csv
# Processing: https://mangacodex.com/oricon_weekly/2008/09_Septiembre.php for 2008-9
# Saved oricon_chart_2008_9.csv
# Processing: https://mangacodex.com/oricon_weekly/2008/10_Octubre.php for 2008-10
# Saved oricon_chart_2008_10.csv
# Processing: https://mangacodex.com/oricon_weekly/2008/11_Noviembre.php for 2008-11
# Saved oricon_chart_2008_11.csv
# Processing: https://mangacodex.com/oricon_weekly/2009/01_NovDec.php for 2009-1
# Saved oricon_chart_2009_1.csv
# Processing: https://mangacodex.com/oricon_weekly/2009/02_Enero.php for 2009-2
# Saved oricon_chart_2009_2.csv
# Processing: https://mangacodex.com/oricon_weekly/2009/03_Febrero.php for 2009-3
# Saved oricon_chart_2009_3.csv
# Processing: https://mangacodex.com/oricon_weekly/2009/04_Marzo.php for 2009-4
# Saved oricon_chart_2009_4.csv
# Processing: https://mangacodex.com/oricon_weekly/2009/05_Abril.php for 2009-5
# Saved oricon_chart_2009_5.csv
# Processing: https://mangacodex.com/oricon_weekly/2009/06_Mayo.php for 2009-6
# Saved oricon_chart_2009_6.csv
# Processing: https://mangacodex.com/oricon_weekly/2009/07_Junio.php for 2009-7
# Saved oricon_chart_2009_7.csv
# Processing: https://mangacodex.com/oricon_weekly/2009/08_Julio.php for 2009-8
# Saved oricon_chart_2009_8.csv
# Processing: https://mangacodex.com/oricon_weekly/2009/09_Agosto.php for 2009-9
# Saved oricon_chart_2009_9.csv
# Processing: https://mangacodex.com/oricon_weekly/2009/10_Septiembre.php for 2009-10
# Saved oricon_chart_2009_10.csv
# Processing: https://mangacodex.com/oricon_weekly/2009/11_Octubre.php for 2009-11
# Saved oricon_chart_2009_11.csv
# Processing: https://mangacodex.com/oricon_weekly/2009/12_Noviembre.php for 2009-12
# Saved oricon_chart_2009_12.csv
# Processing: https://mangacodex.com/oricon_weekly/2010/01_NovDec.php for 2010-1
# Saved oricon_chart_2010_1.csv
# Processing: https://mangacodex.com/oricon_weekly/2010/02_Enero.php for 2010-2
# Saved oricon_chart_2010_2.csv
# Processing: https://mangacodex.com/oricon_weekly/2010/03_Febrero.php for 2010-3
# Saved oricon_chart_2010_3.csv
# Processing: https://mangacodex.com/oricon_weekly/2010/04_Marzo.php for 2010-4
# Saved oricon_chart_2010_4.csv
# Processing: https://mangacodex.com/oricon_weekly/2010/05_Abril.php for 2010-5
# Saved oricon_chart_2010_5.csv
# Processing: https://mangacodex.com/oricon_weekly/2010/06_Mayo.php for 2010-6
# Saved oricon_chart_2010_6.csv
# Processing: https://mangacodex.com/oricon_weekly/2010/07_Junio.php for 2010-7
# Saved oricon_chart_2010_7.csv
# Processing: https://mangacodex.com/oricon_weekly/2010/08_Julio.php for 2010-8
# Saved oricon_chart_2010_8.csv
# Processing: https://mangacodex.com/oricon_weekly/2010/09_Agosto.php for 2010-9
# Saved oricon_chart_2010_9.csv
# Processing: https://mangacodex.com/oricon_weekly/2010/10_Septiembre.php for 2010-10
# Saved oricon_chart_2010_10.csv
# Processing: https://mangacodex.com/oricon_weekly/2010/11_Octubre.php for 2010-11
# Saved oricon_chart_2010_11.csv
# Processing: https://mangacodex.com/oricon_weekly/2010/12_Noviembre.php for 2010-12
# Saved oricon_chart_2010_12.csv
# Processing: https://mangacodex.com/oricon_weekly/2011/01_NovDec.php for 2011-1
# Saved oricon_chart_2011_1.csv
# Processing: https://mangacodex.com/oricon_weekly/2011/02_Enero.php for 2011-2
# Saved oricon_chart_2011_2.csv
# Processing: https://mangacodex.com/oricon_weekly/2011/03_Febrero.php for 2011-3
# Saved oricon_chart_2011_3.csv
# Processing: https://mangacodex.com/oricon_weekly/2011/04_Marzo.php for 2011-4
# Saved oricon_chart_2011_4.csv
# Processing: https://mangacodex.com/oricon_weekly/2011/05_Abril.php for 2011-5
# Saved oricon_chart_2011_5.csv
# Processing: https://mangacodex.com/oricon_weekly/2011/06_Mayo.php for 2011-6
# Saved oricon_chart_2011_6.csv
# Processing: https://mangacodex.com/oricon_weekly/2011/07_Junio.php for 2011-7
# Saved oricon_chart_2011_7.csv
# Processing: https://mangacodex.com/oricon_weekly/2011/08_Julio.php for 2011-8
# Saved oricon_chart_2011_8.csv
# Processing: https://mangacodex.com/oricon_weekly/2011/09_Agosto.php for 2011-9
# Saved oricon_chart_2011_9.csv
# Processing: https://mangacodex.com/oricon_weekly/2011/10_Septiembre.php for 2011-10
# Saved oricon_chart_2011_10.csv
# Processing: https://mangacodex.com/oricon_weekly/2011/11_Octubre.php for 2011-11
# Saved oricon_chart_2011_11.csv
# Processing: https://mangacodex.com/oricon_weekly/2011/12_Noviembre.php for 2011-12
# Saved oricon_chart_2011_12.csv
# Processing: https://mangacodex.com/oricon_weekly/2012/01_NovDec.php for 2012-1
# Saved oricon_chart_2012_1.csv
# Processing: https://mangacodex.com/oricon_weekly/2012/02_Enero.php for 2012-2
# Saved oricon_chart_2012_2.csv
# Processing: https://mangacodex.com/oricon_weekly/2012/03_Febrero.php for 2012-3
# Saved oricon_chart_2012_3.csv
# Processing: https://mangacodex.com/oricon_weekly/2012/04_Marzo.php for 2012-4
# Saved oricon_chart_2012_4.csv
# Processing: https://mangacodex.com/oricon_weekly/2012/05_Abril.php for 2012-5
# Saved oricon_chart_2012_5.csv
# Processing: https://mangacodex.com/oricon_weekly/2012/06_Mayo.php for 2012-6
# Saved oricon_chart_2012_6.csv
# Processing: https://mangacodex.com/oricon_weekly/2012/07_Junio.php for 2012-7
# Saved oricon_chart_2012_7.csv
# Processing: https://mangacodex.com/oricon_weekly/2012/08_Julio.php for 2012-8
# Saved oricon_chart_2012_8.csv
# Processing: https://mangacodex.com/oricon_weekly/2012/09_Agosto.php for 2012-9
# Saved oricon_chart_2012_9.csv
# Processing: https://mangacodex.com/oricon_weekly/2012/10_Septiembre.php for 2012-10
# Saved oricon_chart_2012_10.csv
# Processing: https://mangacodex.com/oricon_weekly/2012/11_Octubre.php for 2012-11
# Saved oricon_chart_2012_11.csv
# Processing: https://mangacodex.com/oricon_weekly/2012/12_Noviembre.php for 2012-12
# Saved oricon_chart_2012_12.csv
# Processing: https://mangacodex.com/oricon_weekly/2013/01_NovDec.php for 2013-1
# Saved oricon_chart_2013_1.csv
# Processing: https://mangacodex.com/oricon_weekly/2013/02_Enero.php for 2013-2
# Saved oricon_chart_2013_2.csv
# Processing: https://mangacodex.com/oricon_weekly/2013/03_Febrero.php for 2013-3
# Saved oricon_chart_2013_3.csv
# Processing: https://mangacodex.com/oricon_weekly/2013/04_Marzo.php for 2013-4
# Saved oricon_chart_2013_4.csv
# Processing: https://mangacodex.com/oricon_weekly/2013/05_Abril.php for 2013-5
# Saved oricon_chart_2013_5.csv
# Processing: https://mangacodex.com/oricon_weekly/2013/06_Mayo.php for 2013-6
# Saved oricon_chart_2013_6.csv
# Processing: https://mangacodex.com/oricon_weekly/2013/07_Junio.php for 2013-7
# Saved oricon_chart_2013_7.csv
# Processing: https://mangacodex.com/oricon_weekly/2013/08_Julio.php for 2013-8
# Saved oricon_chart_2013_8.csv
# Processing: https://mangacodex.com/oricon_weekly/2013/09_Agosto.php for 2013-9
# Saved oricon_chart_2013_9.csv
# Processing: https://mangacodex.com/oricon_weekly/2013/10_Septiembre.php for 2013-10
# Saved oricon_chart_2013_10.csv
# Processing: https://mangacodex.com/oricon_weekly/2013/11_Octubre.php for 2013-11
# Saved oricon_chart_2013_11.csv
# Processing: https://mangacodex.com/oricon_weekly/2013/12_Noviembre.php for 2013-12
# Saved oricon_chart_2013_12.csv
# Processing: https://mangacodex.com/oricon_weekly/2014/01_NovDec.php for 2014-1
# Saved oricon_chart_2014_1.csv
# Processing: https://mangacodex.com/oricon_weekly/2014/02_Enero.php for 2014-2
# Saved oricon_chart_2014_2.csv
# Processing: https://mangacodex.com/oricon_weekly/2014/03_Febrero.php for 2014-3
# Saved oricon_chart_2014_3.csv
# Processing: https://mangacodex.com/oricon_weekly/2014/04_Marzo.php for 2014-4
# Saved oricon_chart_2014_4.csv
# Processing: https://mangacodex.com/oricon_weekly/2014/05_Abril.php for 2014-5
# Saved oricon_chart_2014_5.csv
# Processing: https://mangacodex.com/oricon_weekly/2014/06_Mayo.php for 2014-6
# Saved oricon_chart_2014_6.csv
# Processing: https://mangacodex.com/oricon_weekly/2014/07_Junio.php for 2014-7
# Saved oricon_chart_2014_7.csv
# Processing: https://mangacodex.com/oricon_weekly/2014/08_Julio.php for 2014-8
# Saved oricon_chart_2014_8.csv
# Processing: https://mangacodex.com/oricon_weekly/2014/09_Agosto.php for 2014-9
# Saved oricon_chart_2014_9.csv
# Processing: https://mangacodex.com/oricon_weekly/2014/10_Septiembre.php for 2014-10
# Saved oricon_chart_2014_10.csv
# Processing: https://mangacodex.com/oricon_weekly/2014/11_Octubre.php for 2014-11
# Saved oricon_chart_2014_11.csv
# Processing: https://mangacodex.com/oricon_weekly/2014/12_Noviembre.php for 2014-12
# Saved oricon_chart_2014_12.csv
# Processing: https://mangacodex.com/oricon_weekly/2015/01_NovDec.php for 2015-1
# Saved oricon_chart_2015_1.csv
# Processing: https://mangacodex.com/oricon_weekly/2015/02_Enero.php for 2015-2
# Saved oricon_chart_2015_2.csv
# Processing: https://mangacodex.com/oricon_weekly/2015/03_Febrero.php for 2015-3
# Saved oricon_chart_2015_3.csv
# Processing: https://mangacodex.com/oricon_weekly/2015/04_Marzo.php for 2015-4
# Saved oricon_chart_2015_4.csv
# Processing: https://mangacodex.com/oricon_weekly/2015/05_Abril.php for 2015-5
# Saved oricon_chart_2015_5.csv
# Processing: https://mangacodex.com/oricon_weekly/2015/06_Mayo.php for 2015-6
# Saved oricon_chart_2015_6.csv
# Processing: https://mangacodex.com/oricon_weekly/2015/07_Junio.php for 2015-7
# Saved oricon_chart_2015_7.csv
# Processing: https://mangacodex.com/oricon_weekly/2015/08_Julio.php for 2015-8
# Saved oricon_chart_2015_8.csv
# Processing: https://mangacodex.com/oricon_weekly/2015/09_Agosto.php for 2015-9
# Saved oricon_chart_2015_9.csv
# Processing: https://mangacodex.com/oricon_weekly/2015/10_Septiembre.php for 2015-10
# Saved oricon_chart_2015_10.csv
# Processing: https://mangacodex.com/oricon_weekly/2015/11_Octubre.php for 2015-11
# Saved oricon_chart_2015_11.csv
# Processing: https://mangacodex.com/oricon_weekly/2015/12_Noviembre.php for 2015-12
# Saved oricon_chart_2015_12.csv
# Processing: https://mangacodex.com/oricon_weekly/2016/01_NovDec.php for 2016-1
# Saved oricon_chart_2016_1.csv
# Processing: https://mangacodex.com/oricon_weekly/2016/02_Enero.php for 2016-2
# Saved oricon_chart_2016_2.csv
# Processing: https://mangacodex.com/oricon_weekly/2016/03_Febrero.php for 2016-3
# Saved oricon_chart_2016_3.csv
# Processing: https://mangacodex.com/oricon_weekly/2016/04_Marzo.php for 2016-4
# Saved oricon_chart_2016_4.csv
# Processing: https://mangacodex.com/oricon_weekly/2016/05_Abril.php for 2016-5
# Saved oricon_chart_2016_5.csv
# Processing: https://mangacodex.com/oricon_weekly/2016/06_Mayo.php for 2016-6
# Saved oricon_chart_2016_6.csv
# Processing: https://mangacodex.com/oricon_weekly/2016/07_Junio.php for 2016-7
# Saved oricon_chart_2016_7.csv
# Processing: https://mangacodex.com/oricon_weekly/2016/08_Julio.php for 2016-8
# Saved oricon_chart_2016_8.csv
# Processing: https://mangacodex.com/oricon_weekly/2016/09_Agosto.php for 2016-9
# Saved oricon_chart_2016_9.csv
# Processing: https://mangacodex.com/oricon_weekly/2016/10_Septiembre.php for 2016-10
# Saved oricon_chart_2016_10.csv
# Processing: https://mangacodex.com/oricon_weekly/2016/11_Octubre.php for 2016-11
# Saved oricon_chart_2016_11.csv
# Processing: https://mangacodex.com/oricon_weekly/2016/12_Noviembre.php for 2016-12
# Saved oricon_chart_2016_12.csv
# Processing: https://mangacodex.com/oricon_weekly/2017/01_NovDec.php for 2017-1
# Saved oricon_chart_2017_1.csv
# Processing: https://mangacodex.com/oricon_weekly/2017/02_Enero.php for 2017-2
# Saved oricon_chart_2017_2.csv
# Processing: https://mangacodex.com/oricon_weekly/2017/03_Febrero.php for 2017-3
# Saved oricon_chart_2017_3.csv
# Processing: https://mangacodex.com/oricon_weekly/2017/04_Marzo.php for 2017-4
# Saved oricon_chart_2017_4.csv
# Processing: https://mangacodex.com/oricon_weekly/2017/05_Abril.php for 2017-5
# Saved oricon_chart_2017_5.csv
# Processing: https://mangacodex.com/oricon_weekly/2017/06_Mayo.php for 2017-6
# Saved oricon_chart_2017_6.csv
# Processing: https://mangacodex.com/oricon_weekly/2017/07_Junio.php for 2017-7
# Saved oricon_chart_2017_7.csv
# Processing: https://mangacodex.com/oricon_weekly/2017/08_Julio.php for 2017-8
# Saved oricon_chart_2017_8.csv
# Processing: https://mangacodex.com/oricon_weekly/2017/09_Agosto.php for 2017-9
# Saved oricon_chart_2017_9.csv
# Processing: https://mangacodex.com/oricon_weekly/2017/10_Septiembre.php for 2017-10
# Saved oricon_chart_2017_10.csv
# Processing: https://mangacodex.com/oricon_weekly/2017/11_Octubre.php for 2017-11
# Saved oricon_chart_2017_11.csv
# Processing: https://mangacodex.com/oricon_weekly/2017/12_Noviembre.php for 2017-12
# Saved oricon_chart_2017_12.csv
# Processing: https://mangacodex.com/oricon_weekly/2018/01_NovDec.php for 2018-1
# Saved oricon_chart_2018_1.csv
# Processing: https://mangacodex.com/oricon_weekly/2018/02_Enero.php for 2018-2
# Saved oricon_chart_2018_2.csv
# Processing: https://mangacodex.com/oricon_weekly/2018/03_Febrero.php for 2018-3
# Saved oricon_chart_2018_3.csv
# Processing: https://mangacodex.com/oricon_weekly/2018/04_Marzo.php for 2018-4
# Saved oricon_chart_2018_4.csv
# Processing: https://mangacodex.com/oricon_weekly/2018/05_Abril.php for 2018-5
# Saved oricon_chart_2018_5.csv
# Processing: https://mangacodex.com/oricon_weekly/2018/06_Mayo.php for 2018-6
# Saved oricon_chart_2018_6.csv
# Processing: https://mangacodex.com/oricon_weekly/2018/07_Junio.php for 2018-7
# Saved oricon_chart_2018_7.csv
# Processing: https://mangacodex.com/oricon_weekly/2018/08_Julio.php for 2018-8
# Saved oricon_chart_2018_8.csv
# Processing: https://mangacodex.com/oricon_weekly/2018/09_Agosto.php for 2018-9
# Saved oricon_chart_2018_9.csv
# Processing: https://mangacodex.com/oricon_weekly/2018/10_Septiembre.php for 2018-10
# Saved oricon_chart_2018_10.csv
# Processing: https://mangacodex.com/oricon_weekly/2018/11_Octubre.php for 2018-11
# Saved oricon_chart_2018_11.csv
# Processing: https://mangacodex.com/oricon_weekly/2018/12_Noviembre.php for 2018-12
# Saved oricon_chart_2018_12.csv
# Processing: https://mangacodex.com/oricon_weekly/2019/01_NovDec.php for 2019-1
# Saved oricon_chart_2019_1.csv
# Processing: https://mangacodex.com/oricon_weekly/2019/02_Enero.php for 2019-2
# Saved oricon_chart_2019_2.csv
# Processing: https://mangacodex.com/oricon_weekly/2019/03_Febrero.php for 2019-3
# Saved oricon_chart_2019_3.csv
# Processing: https://mangacodex.com/oricon_weekly/2019/04_Marzo.php for 2019-4
# Saved oricon_chart_2019_4.csv
# Processing: https://mangacodex.com/oricon_weekly/2019/05_Abril.php for 2019-5
# Saved oricon_chart_2019_5.csv
# Processing: https://mangacodex.com/oricon_weekly/2019/06_Mayo.php for 2019-6
# Saved oricon_chart_2019_6.csv
# Processing: https://mangacodex.com/oricon_weekly/2019/07_Junio.php for 2019-7
# Saved oricon_chart_2019_7.csv
# Processing: https://mangacodex.com/oricon_weekly/2019/08_Julio.php for 2019-8
# Saved oricon_chart_2019_8.csv
# Processing: https://mangacodex.com/oricon_weekly/2019/09_Agosto.php for 2019-9
# Saved oricon_chart_2019_9.csv
# Processing: https://mangacodex.com/oricon_weekly/2019/10_Septiembre.php for 2019-10
# Saved oricon_chart_2019_10.csv
# Processing: https://mangacodex.com/oricon_weekly/2019/11_Octubre.php for 2019-11
# Saved oricon_chart_2019_11.csv
# Processing: https://mangacodex.com/oricon_weekly/2019/12_Noviembre.php for 2019-12
# Saved oricon_chart_2019_12.csv
# Processing: https://mangacodex.com/oricon_weekly/2020/01_NovDec.php for 2020-1
# Saved oricon_chart_2020_1.csv
# Processing: https://mangacodex.com/oricon_weekly/2020/02_Enero.php for 2020-2
# Saved oricon_chart_2020_2.csv
# Processing: https://mangacodex.com/oricon_weekly/2020/03_Febrero.php for 2020-3
# Saved oricon_chart_2020_3.csv
# Processing: https://mangacodex.com/oricon_weekly/2020/04_Marzo.php for 2020-4
# Saved oricon_chart_2020_4.csv
# Processing: https://mangacodex.com/oricon_weekly/2020/05_Abril.php for 2020-5
# Saved oricon_chart_2020_5.csv
# Processing: https://mangacodex.com/oricon_weekly/2020/06_Mayo.php for 2020-6
# Saved oricon_chart_2020_6.csv
# Processing: https://mangacodex.com/oricon_weekly/2020/07_Junio.php for 2020-7
# Saved oricon_chart_2020_7.csv
# Processing: https://mangacodex.com/oricon_weekly/2020/08_Julio.php for 2020-8
# Saved oricon_chart_2020_8.csv
# Processing: https://mangacodex.com/oricon_weekly/2020/09_Agosto.php for 2020-9
# Saved oricon_chart_2020_9.csv
# Processing: https://mangacodex.com/oricon_weekly/2020/10_Septiembre.php for 2020-10
# Saved oricon_chart_2020_10.csv
# Processing: https://mangacodex.com/oricon_weekly/2020/11_Octubre.php for 2020-11
# Saved oricon_chart_2020_11.csv
# Processing: https://mangacodex.com/oricon_weekly/2020/12_Noviembre.php for 2020-12
# Saved oricon_chart_2020_12.csv
# Processing: https://mangacodex.com/oricon_weekly/2021/01_NovDec.php for 2021-1
# Saved oricon_chart_2021_1.csv
# Processing: https://mangacodex.com/oricon_weekly/2021/02_Enero.php for 2021-2
# Saved oricon_chart_2021_2.csv
# Processing: https://mangacodex.com/oricon_weekly/2021/03_Febrero.php for 2021-3
# Saved oricon_chart_2021_3.csv
# Processing: https://mangacodex.com/oricon_weekly/2021/04_Marzo.php for 2021-4
# Saved oricon_chart_2021_4.csv
# Processing: https://mangacodex.com/oricon_weekly/2021/05_Abril.php for 2021-5
# Saved oricon_chart_2021_5.csv
# Processing: https://mangacodex.com/oricon_weekly/2021/06_Mayo.php for 2021-6
# Saved oricon_chart_2021_6.csv
# Processing: https://mangacodex.com/oricon_weekly/2021/07_Junio.php for 2021-7
# Saved oricon_chart_2021_7.csv
# Processing: https://mangacodex.com/oricon_weekly/2021/08_Julio.php for 2021-8
# Saved oricon_chart_2021_8.csv
# Processing: https://mangacodex.com/oricon_weekly/2021/09_Agosto.php for 2021-9
# Saved oricon_chart_2021_9.csv
# Processing: https://mangacodex.com/oricon_weekly/2021/10_Septiembre.php for 2021-10
# Saved oricon_chart_2021_10.csv
# Processing: https://mangacodex.com/oricon_weekly/2021/11_Octubre.php for 2021-11
# Saved oricon_chart_2021_11.csv
# Processing: https://mangacodex.com/oricon_weekly/2021/12_Noviembre.php for 2021-12
# Saved oricon_chart_2021_12.csv
# Processing: https://mangacodex.com/oricon_weekly/2022/01_NovDec.php for 2022-1
# Saved oricon_chart_2022_1.csv
# Processing: https://mangacodex.com/oricon_weekly/2022/02_Enero.php for 2022-2
# Saved oricon_chart_2022_2.csv
# Processing: https://mangacodex.com/oricon_weekly/2022/03_Febrero.php for 2022-3
# Saved oricon_chart_2022_3.csv
# Processing: https://mangacodex.com/oricon_weekly/2022/04_Marzo.php for 2022-4
# Saved oricon_chart_2022_4.csv
# Processing: https://mangacodex.com/oricon_weekly/2022/05_Abril.php for 2022-5
# Saved oricon_chart_2022_5.csv
# Processing: https://mangacodex.com/oricon_weekly/2022/06_Mayo.php for 2022-6
# Saved oricon_chart_2022_6.csv
# Processing: https://mangacodex.com/oricon_weekly/2022/07_Junio.php for 2022-7
# Saved oricon_chart_2022_7.csv
# Processing: https://mangacodex.com/oricon_weekly/2022/08_Julio.php for 2022-8
# Saved oricon_chart_2022_8.csv
# Processing: https://mangacodex.com/oricon_weekly/2022/09_Agosto.php for 2022-9
# Saved oricon_chart_2022_9.csv
# Processing: https://mangacodex.com/oricon_weekly/2022/10_Septiembre.php for 2022-10
# Saved oricon_chart_2022_10.csv
# Processing: https://mangacodex.com/oricon_weekly/2022/11_Octubre.php for 2022-11
# Saved oricon_chart_2022_11.csv
# Processing: https://mangacodex.com/oricon_weekly/2022/12_Noviembre.php for 2022-12
# Saved oricon_chart_2022_12.csv
# Processing: https://mangacodex.com/oricon_weekly/2023/01_NovDec.php for 2023-1
# Saved oricon_chart_2023_1.csv
# Processing: https://mangacodex.com/oricon_weekly/2023/02_Enero.php for 2023-2
# Saved oricon_chart_2023_2.csv
# Processing: https://mangacodex.com/oricon_weekly/2023/03_Febrero.php for 2023-3
# Saved oricon_chart_2023_3.csv
# Processing: https://mangacodex.com/oricon_weekly/2023/04_Marzo.php for 2023-4
# Saved oricon_chart_2023_4.csv
# Processing: https://mangacodex.com/oricon_weekly/2023/05_Abril.php for 2023-5
# Saved oricon_chart_2023_5.csv
# Processing: https://mangacodex.com/oricon_weekly/2023/06_Mayo.php for 2023-6
# Saved oricon_chart_2023_6.csv
# Processing: https://mangacodex.com/oricon_weekly/2023/07_Junio.php for 2023-7
# Saved oricon_chart_2023_7.csv
# Processing: https://mangacodex.com/oricon_weekly/2023/08_Julio.php for 2023-8
# Saved oricon_chart_2023_8.csv
# Processing: https://mangacodex.com/oricon_weekly/2023/09_Agosto.php for 2023-9
# Saved oricon_chart_2023_9.csv
# Processing: https://mangacodex.com/oricon_weekly/2023/10_Septiembre.php for 2023-10
# Saved oricon_chart_2023_10.csv
# Processing: https://mangacodex.com/oricon_weekly/2023/11_Octubre.php for 2023-11
# Saved oricon_chart_2023_11.csv
# Processing: https://mangacodex.com/oricon_weekly/2023/12_Noviembre.php for 2023-12
# Saved oricon_chart_2023_12.csv
